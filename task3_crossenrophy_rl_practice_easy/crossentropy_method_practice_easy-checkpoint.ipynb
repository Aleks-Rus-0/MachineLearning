# %% [markdown]
# # Crossentropy method
#
# This notebook will teach you to solve reinforcement learning problems with crossentropy method. We'll follow-up by scaling everything up and using neural network policy.

# %%
import os

# %%
import gymnasium as gym
import numpy as np, pandas as pd

env = gym.make("Taxi-v3",render_mode='ansi')
env.reset()
print(env.render())
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n

print("n_states=%i, n_actions=%i"%(n_states,n_actions))
# Out:
# n_states=500, n_actions=6

# %% [markdown]
# # Create stochastic policy
#
# This time our policy should be a probability distribution.
#
# ```policy[s,a] = P(take action a | in state s)```
#
# Since we still use integer state and action representations, you can use a 2-dimensional array to represent the policy.
#
# Please initialize policy __uniformly__, that is, probabililities of all actions should be equal.

# %% [markdown]
# # Initialize policy (0.5pts)

# %%
policy = np.ones((n_states, n_actions)) / n_actions

assert type(policy) in (np.ndarray,np.matrix)
assert np.allclose(policy,1./n_actions)
assert np.allclose(np.sum(policy,axis=1), 1)
print("Ok!")
# Out:
# Ok!

# %% [markdown]
# # Play the game (0.5pts)
#
# Just like before, but we also record all states and actions we took.

# %%
def generate_session(policy,t_max=10**4):

    states,actions = [],[]
    total_reward = 0.
    
    s = env.reset()[0]
    
    for t in range(t_max):
        a = np.random.choice(range(n_actions), p = policy[s])
        
        new_s, r, terminated, truncated, info = env.step(a)
        done = terminated or truncated

        states.append(s)
        actions.append(a)
        total_reward += r
        
        s = new_s
        if done:
            break
    return states,actions,total_reward

# %%
s,a,r = generate_session(policy)
assert type(s) == type(a) == list
assert len(s) == len(a)
assert type(r) in [float,float]

# %%
#let's see the initial reward distribution
import matplotlib.pyplot as plt
# %matplotlib inline

sample_rewards = [generate_session(policy,t_max=1000)[-1] for _ in range(200)]

plt.hist(sample_rewards,bins=20);
plt.vlines([np.percentile(sample_rewards,50)],[0],[100],label="50'th percentile",color='green')
plt.vlines([np.percentile(sample_rewards,90)],[0],[100],label="90'th percentile",color='red')
plt.legend()

# %% [markdown]
# ### Crossentropy method steps (1pts)

# %%
def select_elites(states_batch,actions_batch,rewards_batch,percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]
    
    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions
    
    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]
    
    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """ 


    reward_threshold = np.percentile(rewards_batch, percentile)
    
    elite_indices = [i for i, reward in enumerate(rewards_batch) if reward >= reward_threshold]
    
    elite_states = []
    elite_actions = []
    
    for idx in elite_indices:
        elite_states.extend(states_batch[idx])
        elite_actions.extend(actions_batch[idx])
    
    elite_states = np.array(elite_states)
    elite_actions = np.array(elite_actions)
    
    return elite_states, elite_actions

# %%
states_batch = [
    np.array([1,2,3]),   #game1
    np.array([4,2,0,2]), #game2
    np.array([3,1])      #game3
]

actions_batch = [
    np.array([0,2,4]),   #game1
    np.array([3,2,0,1]), #game2
    np.array([3,3])      #game3
]
rewards_batch = np.array([
    3,         #game1
    4,         #game2
    5,         #game3
])

test_result_0 = select_elites(states_batch,actions_batch,rewards_batch,percentile=0)
test_result_40 = select_elites(states_batch,actions_batch,rewards_batch,percentile=30)
test_result_90 = select_elites(states_batch,actions_batch,rewards_batch,percentile=90)
test_result_100 = select_elites(states_batch,actions_batch,rewards_batch,percentile=100)

assert np.all(test_result_0[0] == [1, 2, 3, 4, 2, 0, 2, 3, 1])  \
   and np.all(test_result_0[1] == [0, 2, 4, 3, 2, 0, 1, 3, 3]),\
        "For percentile 0 you should return all states and actions in chronological order"
assert np.all(test_result_40[0] == [4, 2, 0, 2, 3, 1]) and \
        np.all(test_result_40[1] ==[3, 2, 0, 1, 3, 3]),\
        "For percentile 30 you should only select states/actions from two first"
assert np.all(test_result_90[0] == [3,1]) and \
        np.all(test_result_90[1] == [3,3]),\
        "For percentile 90 you should only select states/actions from one game"
assert np.all(test_result_100[0] == [3,1]) and\
       np.all(test_result_100[1] == [3,3]),\
        "Please make sure you use >=, not >. Also double-check how you compute percentile."
print("Ok!")
# Out:
# Ok!

# %%
def update_policy(elite_states,elite_actions):
    """
    Given old policy and a list of elite states/actions from select_elites,
    return new updated policy where each action probability is proportional to
    
    policy[s_i,a_i] ~ #[occurences of si and ai in elite states/actions]
    
    Don't forget to normalize policy to get valid probabilities and handle 0/0 case.
    In case you never visited a state, set probabilities for all actions to 1./n_actions
    
    :param elite_states: 1D list of states from elite sessions
    :param elite_actions: 1D list of actions from elite sessions
    
    """
    
    new_policy = np.zeros([n_states,n_actions])
    
    for state, action in zip(elite_states, elite_actions):
        new_policy[state, action] += 1
    
    for state in range(n_states):
        row_sum = np.sum(new_policy[state])
        if row_sum > 0:
            new_policy[state] /= row_sum
        else:
            new_policy[state] = 1.0 / n_actions
    
    return new_policy

# %%
elite_states, elite_actions = ([1, 2, 3, 4, 2, 0, 2, 3, 1], [0, 2, 4, 3, 2, 0, 1, 3, 3])


new_policy = update_policy(elite_states,elite_actions)

assert np.isfinite(new_policy).all(), "Your new policy contains NaNs or +-inf. Make sure you don't divide by zero."
assert np.all(new_policy>=0), "Your new policy can't have negative action probabilities"
assert np.allclose(new_policy.sum(axis=-1),1), "Your new policy should be a valid probability distribution over actions"
reference_answer = np.array([
       [ 1.        ,  0.        ,  0.        ,  0.        ,  0.        ],
       [ 0.5       ,  0.        ,  0.        ,  0.5       ,  0.        ],
       [ 0.        ,  0.33333333,  0.66666667,  0.        ,  0.        ],
       [ 0.        ,  0.        ,  0.        ,  0.5       ,  0.5       ]])
print(new_policy[:4,:5])
assert np.allclose(new_policy[:4,:5],reference_answer)
print("Ok!")
# Out:
# [[1.         0.         0.         0.         0.        ]
#  [0.5        0.         0.         0.5        0.        ]
#  [0.         0.33333333 0.66666667 0.         0.        ]
#  [0.         0.         0.         0.5        0.5       ]]
# Ok!

# %% [markdown]
# # Training loop (1pts)
# Generate sessions, select N best and fit to those.

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

def show_progress(rewards_batch,log, reward_range=[-990,+10]):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """
    
    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch, percentile)
    log.append([mean_reward,threshold])

    clear_output(True)
    print("mean reward =", mean_reward,  "threshold =", mean_reward,threshold)

    plt.figure(figsize=[8,4])
    plt.subplot(1,2,1)
    plt.plot(list(zip(*log))[0],label='Mean rewards')
    plt.plot(list(zip(*log))[1],label='Reward thresholds')

    plt.legend()
    plt.grid()
    
    plt.subplot(1,2,2)
    plt.hist(rewards_batch,range=reward_range)
    plt.vlines([np.percentile(rewards_batch, percentile)],[0],[100],label="percentile",color='red')
    plt.legend()
    plt.grid()

    plt.show()

# %%
#reset policy just in case
policy = np.ones((n_states, n_actions)) / n_actions

# %%
n_sessions = 250  #sample this many sessions
percentile = 70  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability

log = []

for i in range(100):
    
    # %time sessions = [generate_session(policy) for _ in range(n_sessions)]
    
    states_batch,actions_batch,rewards_batch = zip(*sessions)

    elite_states, elite_actions = select_elites(np.array(states_batch, dtype=object), 
                                                np.array(actions_batch, dtype=object), 
                                                np.array(rewards_batch, dtype=object),
                                                percentile=percentile)
    
    new_policy = update_policy(elite_states,elite_actions)
    
    policy = learning_rate * new_policy + (1 - learning_rate) * policy
    
    #display results on chart
    show_progress(rewards_batch,log)
# Out:
# mean reward = -344.928, threshold=1.900

# %% [markdown]
# # Tabular crossentropy method
#
# You may have noticed that the taxi problem quickly converges from -100 to a near-optimal score and then descends back into -50/-100. This is in part because the environment has some innate randomness. Namely, the starting points of passenger/driver change from episode to episode.
#
# ### Tasks
# - __1.1__ (1 pts) Find out how the algorithm performance changes if you change different percentile and different n_samples. Show all precentiles on one graph and all n_samples on another
# - __1.2__ (1 pts) Tune the algorithm to end up with positive average score.
#
# It's okay to modify the existing code.

# %%
import gymnasium as gym
import numpy as np, pandas as pd

env = gym.make("Taxi-v3", render_mode='ansi')
env.reset()
n_states = env.observation_space.n
n_actions = env.action_space.n
policy = 1/6. * np.ones([n_states, n_actions])
assert type(policy) in (np.ndarray,np.matrix)
assert np.allclose(policy,1./n_actions)
assert np.allclose(np.sum(policy,axis=1), 1)
s,a,r = generate_session(policy)
assert type(s) == type(a) == list
assert len(s) == len(a)
assert type(r) in [float, float]
policy = np.ones([n_states,n_actions])/n_actions 
stepCounter = 40

# %%
n_sessions = 250  #sample this many sessions
percentiles = [10, 20, 30, 40, 50]  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability
stepCounter = 10

log = []
mean = []
for percentile in percentiles:
    curMean = []
    policy = np.ones([n_states,n_actions])/n_actions
    for i in range(stepCounter):

        # %time sessions = [generate_session(policy) for _ in range(n_sessions)]

        states_batch,actions_batch,rewards_batch = zip(*sessions)

        elite_states, elite_actions = select_elites(np.array(states_batch, dtype=object), 
                                                np.array(actions_batch, dtype=object), 
                                                np.array(rewards_batch, dtype=object),
                                                percentile=percentile)
    
        new_policy = update_policy(elite_states,elite_actions)
        policy = learning_rate * new_policy + (1 - learning_rate) * policy
        curMean.append(np.mean(rewards_batch))

        #set new policy
        #update policy
        #add mean value
        
        clear_output(True)
    mean.append(curMean)
# display results on chart
# show_progress(rewards_batch,log)

for i in range(len(percentiles)):
    print(percentiles[i], f"mean: {mean[i][-1]}")

plt.figure(figsize=[8,4])
plt.subplot(1,2,1)
plt.xlabel('Iteration') 
plt.ylabel('Mean Reward')
for i in range(len(percentiles)):
    plt.plot(range(stepCounter), mean[i], label=f'percentile {percentiles[i]}')
plt.legend()
plt.grid()

plt.show()
# Out:
# 10 mean: -698.796
# 20 mean: -631.4
# 30 mean: -566.604
# 40 mean: -483.408
# 50 mean: -391.752

# %% [markdown]
# # How do different percentiles affect training efficiency?

# %%
# Describe your observations

# %%
n_sessions_ar = []  #sample this many sessions
perc = 70  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability

log = []
mean = []
for n_sessions in n_sessions_ar:
    curMean = []
    policy = np.ones([n_states,n_actions])/n_actions
    for i in range(stepCounter):

        # %time sessions = [generate_session(policy) for _ in range(n_sessions)]

        states_batch,actions_batch,rewards_batch = zip(*sessions)

        elite_states, elite_actions = select_elites(np.array(states_batch),
                                                    np.array(actions_batch),np.array(rewards_batch),percentile=perc)

        #set new policy
        #update policy
        #add mean value
        clear_output(True)
    mean.append(curMean)
    #display results on chart
    #show_progress(rewards_batch,log)

# %% [markdown]
# # Stabilize positive rewards by averaging policy across 10 games (2 pts)

# %%
def generate_session(policy,t_max=10**4):

    states,actions = [],[]
    total_reward = 0.
    
    s = env.reset()[0]
    
    for t in range(t_max):
        a = np.random.choice(range(n_actions), p = policy[s])
        
        new_s, r, terminated, truncated, info = env.step(a)
        done = terminated or truncated

        states.append(s)
        actions.append(a)
        total_reward += r
        
        s = new_s
        if done:
            break
    return states,actions,total_reward

# %%
n_sessions = 400  #sample this many sessions
percentile = 10  #take this percent of session with highest rewards
learning_rate = 0.2  #add this thing to all counts for stability

log = []
mean = []
policy = np.ones([n_states,n_actions]) / n_actions

for i in range(100):

    # %time sessions = [generate_session(policy) for _ in range(n_sessions)]

    states_batch,actions_batch,rewards_batch = zip(*sessions)


    elite_states, elite_actions = select_elites(np.array(states_batch, dtype=object), 
                                            np.array(actions_batch, dtype=object), 
                                            np.array(rewards_batch, dtype=object),
                                            percentile=percentile)
    
    
    
    if(np.mean(rewards_batch) > 7):
        print("win!")
        break
# Out:
# CPU times: user 0 ns, sys: 460 μs, total: 460 μs
# Wall time: 466 μs
# CPU times: user 350 μs, sys: 0 ns, total: 350 μs
# Wall time: 356 μs
# CPU times: user 362 μs, sys: 0 ns, total: 362 μs
# Wall time: 370 μs
# CPU times: user 366 μs, sys: 6 μs, total: 372 μs
# Wall time: 400 μs
# CPU times: user 443 μs, sys: 8 μs, total: 451 μs
# Wall time: 459 μs
# CPU times: user 480 μs, sys: 0 ns, total: 480 μs
# Wall time: 489 μs
# CPU times: user 805 μs, sys: 0 ns, total: 805 μs
# Wall time: 827 μs
# CPU times: user 642 μs, sys: 0 ns, total: 642 μs
# Wall time: 657 μs
# CPU times: user 445 μs, sys: 0 ns, total: 445 μs
# Wall time: 458 μs
# CPU times: user 328 μs, sys: 0 ns, total: 328 μs
# Wall time: 335 μs
# CPU times: user 557 μs, sys: 0 ns, total: 557 μs
# Wall time: 562 μs
# CPU times: user 294 μs, sys: 0 ns, total: 294 μs
# Wall time: 298 μs
# CPU times: user 322 μs, sys: 0 ns, total: 322 μs
# Wall time: 327 μs
# CPU times: user 290 μs, sys: 0 ns, total: 290 μs
# Wall time: 294 μs
# CPU times: user 263 μs, sys: 0 ns, total: 263 μs
# Wall time: 266 μs
# CPU times: user 189 μs, sys: 0 ns, total: 189 μs
# Wall time: 193 μs
# CPU times: user 248 μs, sys: 0 ns, total: 248 μs
# Wall time: 251 μs
# CPU times: user 197 μs, sys: 0 ns, total: 197 μs
# Wall time: 200 μs
# CPU times: user 179 μs, sys: 0 ns, total: 179 μs
# Wall time: 182 μs
# CPU times: user 322 μs, sys: 0 ns, total: 322 μs
# Wall time: 326 μs
# CPU times: user 248 μs, sys: 0 ns, total: 248 μs
# Wall time: 251 μs
# CPU times: user 217 μs, sys: 0 ns, total: 217 μs
# Wall time: 220 μs
# CPU times: user 274 μs, sys: 0 ns, total: 274 μs
# Wall time: 277 μs
# CPU times: user 250 μs, sys: 0 ns, total: 250 μs
# Wall time: 254 μs
# CPU times: user 247 μs, sys: 0 ns, total: 247 μs
# Wall time: 251 μs
# CPU times: user 274 μs, sys: 0 ns, total: 274 μs
# Wall time: 278 μs
# CPU times: user 336 μs, sys: 0 ns, total: 336 μs
# Wall time: 340 μs
# CPU times: user 295 μs, sys: 0 ns, total: 295 μs
# Wall time: 299 μs
# CPU times: user 267 μs, sys: 0 ns, total: 267 μs
# Wall time: 271 μs
# CPU times: user 274 μs, sys: 0 ns, total: 274 μs
# Wall time: 278 μs
# CPU times: user 280 μs, sys: 0 ns, total: 280 μs
# Wall time: 283 μs
# CPU times: user 295 μs, sys: 0 ns, total: 295 μs
# Wall time: 300 μs
# CPU times: user 287 μs, sys: 0 ns, total: 287 μs
# Wall time: 291 μs
# CPU times: user 282 μs, sys: 0 ns, total: 282 μs
# Wall time: 286 μs
# CPU times: user 330 μs, sys: 0 ns, total: 330 μs
# Wall time: 334 μs
# CPU times: user 255 μs, sys: 0 ns, total: 255 μs
# Wall time: 258 μs
# CPU times: user 255 μs, sys: 0 ns, total: 255 μs
# Wall time: 258 μs
# CPU times: user 285 μs, sys: 0 ns, total: 285 μs
# Wall time: 289 μs
# CPU times: user 327 μs, sys: 0 ns, total: 327 μs
# Wall time: 331 μs
# CPU times: user 248 μs, sys: 0 ns, total: 248 μs
# Wall time: 252 μs
# CPU times: user 213 μs, sys: 0 ns, total: 213 μs
# Wall time: 216 μs
# CPU times: user 211 μs, sys: 0 ns, total: 211 μs
# Wall time: 215 μs
# CPU times: user 256 μs, sys: 0 ns, total: 256 μs
# Wall time: 260 μs
# CPU times: user 259 μs, sys: 0 ns, total: 259 μs
# Wall time: 263 μs
# CPU times: user 254 μs, sys: 0 ns, total: 254 μs
# Wall time: 258 μs
# CPU times: user 250 μs, sys: 0 ns, total: 250 μs
# Wall time: 253 μs
# CPU times: user 330 μs, sys: 0 ns, total: 330 μs
# Wall time: 334 μs
# CPU times: user 196 μs, sys: 0 ns, total: 196 μs
# Wall time: 200 μs
# CPU times: user 170 μs, sys: 0 ns, total: 170 μs
# Wall time: 181 μs
# CPU times: user 242 μs, sys: 0 ns, total: 242 μs
# Wall time: 244 μs
# CPU times: user 252 μs, sys: 0 ns, total: 252 μs
# Wall time: 256 μs
# CPU times: user 177 μs, sys: 0 ns, total: 177 μs
# Wall time: 180 μs
# CPU times: user 170 μs, sys: 0 ns, total: 170 μs
# Wall time: 173 μs
# CPU times: user 268 μs, sys: 0 ns, total: 268 μs
# Wall time: 271 μs
# CPU times: user 192 μs, sys: 0 ns, total: 192 μs
# Wall time: 195 μs
# CPU times: user 193 μs, sys: 0 ns, total: 193 μs
# Wall time: 196 μs
# CPU times: user 163 μs, sys: 0 ns, total: 163 μs
# Wall time: 166 μs
# CPU times: user 240 μs, sys: 0 ns, total: 240 μs
# Wall time: 243 μs
# CPU times: user 334 μs, sys: 0 ns, total: 334 μs
# Wall time: 337 μs
# CPU times: user 165 μs, sys: 0 ns, total: 165 μs
# Wall time: 169 μs
# CPU times: user 234 μs, sys: 0 ns, total: 234 μs
# Wall time: 237 μs
# CPU times: user 234 μs, sys: 0 ns, total: 234 μs
# Wall time: 275 μs
# CPU times: user 201 μs, sys: 0 ns, total: 201 μs
# Wall time: 204 μs
# CPU times: user 172 μs, sys: 0 ns, total: 172 μs
# Wall time: 175 μs
# CPU times: user 256 μs, sys: 0 ns, total: 256 μs
# Wall time: 259 μs
# CPU times: user 199 μs, sys: 0 ns, total: 199 μs
# Wall time: 202 μs
# CPU times: user 166 μs, sys: 3 μs, total: 169 μs
# Wall time: 172 μs
# CPU times: user 203 μs, sys: 0 ns, total: 203 μs
# Wall time: 207 μs
# CPU times: user 250 μs, sys: 4 μs, total: 254 μs
# Wall time: 257 μs
# CPU times: user 238 μs, sys: 0 ns, total: 238 μs
# Wall time: 241 μs
# CPU times: user 344 μs, sys: 0 ns, total: 344 μs
# Wall time: 389 μs
# CPU times: user 247 μs, sys: 0 ns, total: 247 μs
# Wall time: 250 μs
# CPU times: user 292 μs, sys: 0 ns, total: 292 μs
# Wall time: 297 μs
# CPU times: user 300 μs, sys: 0 ns, total: 300 μs
# Wall time: 361 μs
# CPU times: user 297 μs, sys: 0 ns, total: 297 μs
# Wall time: 301 μs
# CPU times: user 306 μs, sys: 0 ns, total: 306 μs
# Wall time: 311 μs
# CPU times: user 349 μs, sys: 0 ns, total: 349 μs
# Wall time: 355 μs
# CPU times: user 208 μs, sys: 0 ns, total: 208 μs
# Wall time: 211 μs
# CPU times: user 426 μs, sys: 0 ns, total: 426 μs
# Wall time: 435 μs
# CPU times: user 282 μs, sys: 0 ns, total: 282 μs
# Wall time: 286 μs
# CPU times: user 312 μs, sys: 0 ns, total: 312 μs
# Wall time: 364 μs
# CPU times: user 274 μs, sys: 0 ns, total: 274 μs
# Wall time: 278 μs
# CPU times: user 406 μs, sys: 0 ns, total: 406 μs
# Wall time: 411 μs
# CPU times: user 345 μs, sys: 0 ns, total: 345 μs
# Wall time: 350 μs
# CPU times: user 451 μs, sys: 0 ns, total: 451 μs
# Wall time: 461 μs
# CPU times: user 404 μs, sys: 0 ns, total: 404 μs
# Wall time: 413 μs
# CPU times: user 302 μs, sys: 0 ns, total: 302 μs
# Wall time: 306 μs
# CPU times: user 292 μs, sys: 0 ns, total: 292 μs
# Wall time: 296 μs
# CPU times: user 320 μs, sys: 0 ns, total: 320 μs
# Wall time: 324 μs
# CPU times: user 302 μs, sys: 0 ns, total: 302 μs
# Wall time: 345 μs
# CPU times: user 337 μs, sys: 0 ns, total: 337 μs
# Wall time: 343 μs
# CPU times: user 281 μs, sys: 0 ns, total: 281 μs
# Wall time: 284 μs
# CPU times: user 340 μs, sys: 0 ns, total: 340 μs
# Wall time: 344 μs
# CPU times: user 307 μs, sys: 0 ns, total: 307 μs
# Wall time: 311 μs
# CPU times: user 424 μs, sys: 0 ns, total: 424 μs
# Wall time: 430 μs
# CPU times: user 332 μs, sys: 0 ns, total: 332 μs
# Wall time: 337 μs
# CPU times: user 436 μs, sys: 0 ns, total: 436 μs
# Wall time: 445 μs
# CPU times: user 373 μs, sys: 0 ns, total: 373 μs
# Wall time: 379 μs
# CPU times: user 328 μs, sys: 0 ns, total: 328 μs
# Wall time: 335 μs
# CPU times: user 321 μs, sys: 0 ns, total: 321 μs
# Wall time: 325 μs

# %% [markdown]
# # Digging deeper: approximate crossentropy with neural nets (2 pts)
#
# In this section we will train a neural network policy for continuous state space game

# %%
import gym
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
env = gym.make("CartPole-v0").env  #if you see "<classname> has no attribute .env", remove .env or update gym

env.reset()
n_actions = env.action_space.n

plt.imshow(env.render("rgb_array"))

# %% [markdown]
# In this case use NN as a black box. All your should know that it is more complex than a tabular method.

# %%
#create agent
from sklearn.neural_network import MLPClassifier
agent = MLPClassifier(hidden_layer_sizes=(20,20),
                      activation='tanh',
                      warm_start=True, #keep progress between .fit(...) calls
                      max_iter=1 #make only 1 iteration on each .fit(...)
                     )
#initialize agent to the dimension of state an amount of actions
agent.fit([env.reset()]*n_actions,range(n_actions));

# %%
def generate_session(t_max=1000):
    
    states,actions = [],[]
    total_reward = 0
    
    s = env.reset()
    
    for t in range(t_max):
        
        #predict array of action probabilities hint: predict_proba
        
        
        a = np.random.choice(np.arange(n_actions), p=probs)
        
        new_s,r,done,info = env.step(a)
        
        #record sessions like you did before
        
        
        s = new_s
        if done: break
    return states,actions,total_reward

# %%
def select_elites(states_batch,actions_batch,rewards_batch,percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]
    
    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions
    
    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]
    
    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """ 
    reward_threshold = np.percentile(rewards_batch,percentile)
    
    elite_states = []
    
    if(len(np.array(states_batch[0]).shape) == 1):
        elite_states = np.hstack(states_batch[rewards_batch >= reward_threshold])
    else:
        elite_states = np.vstack(states_batch[rewards_batch >= reward_threshold])
    elite_actions = np.hstack(actions_batch[rewards_batch >= reward_threshold])
    
    return elite_states,elite_actions

# %% [markdown]
# To train this classification model use fit(states, actions). In this case we are training classificator to predict the correct class (action) in a given state

# %%
n_sessions = 100
percentile = 70
log = []

for i in range(100):
    #generate new sessions
    sessions = [generate_session() for _ in range(n_sessions)]

    states_batch,actions_batch,rewards_batch = map(np.array,zip(*sessions))
    print(states_batch.shape)

    elite_states, elite_actions = select_elites(states_batch,actions_batch,rewards_batch,percentile=50)
    
    #fit agent

    show_progress(rewards_batch,log,reward_range=[0,np.max(rewards_batch)])
    
    if np.mean(rewards_batch)> 190:
        print("You Win! You may stop training now via KeyboardInterrupt.")
        break

# %% [markdown]
# # Report (1 pts)

# %%
# Describe what you did here.  Preferably with plot/report to support it
