# %% [markdown]
# # Кластеризация ЕГЭ (8.5 если сделаны все задачи)

# %% [markdown]
# Рядом лежат экселевские таблицы с координатами точек. В 3 и 4 задаче используется манхетеское расстояние. В остальных Евклидово.
#
# * Постройте Распределение точек
# * Кластеризуйте руками
# * Постройте Распределение точек, отметьте принадлежность кластеров цветами
# * Найдите среди в каждом кластере точку расстояние от которой до всех остальных минимально
# * Выведите усреднение центров всех кластеров * 1000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel("0.xls")

X = np.array(df['X'])
Y = np.array(df['Y'])

k = 3
b = 3

x_line = [-0.5, 3.0]
y_line = [k * -0.5 + b, k * 3.0 + b]

cluster_0_x = []
cluster_0_y = []
cluster_1_x = []
cluster_1_y = []

for i in range(len(X)):
    if Y[i] > k * X[i] + b:
        cluster_0_x.append(X[i])
        cluster_0_y.append(Y[i])
    else:
        cluster_1_x.append(X[i])
        cluster_1_y.append(Y[i])
# plt.plot(x_line, y_line, color="red")
plt.scatter(cluster_0_x, cluster_0_y, color="blue", label="cluster_0")
plt.scatter(cluster_1_x, cluster_1_y, color="green", label="cluster_1")

plt.grid(True)
plt.legend()
plt.show()

clusters = [
    (np.array([cluster_0_x, cluster_0_y]).T, "cluster_0"),
    (np.array([cluster_1_x, cluster_1_y]).T, "cluster_1")
]

all_centers = []
for cluster_points, cluster_name in clusters:
    if len(cluster_points) > 0:
        min_sum_dist = float('inf')
        central_point = None
        for i, point in enumerate(cluster_points):
            sum_dist = np.sum(np.sqrt(np.sum((cluster_points - point) ** 2, axis=1)))
            if sum_dist < min_sum_dist:
                min_sum_dist = sum_dist
                central_point = point
        print(f"{cluster_name}: центральная точка = {central_point}")
        
        center = np.mean(cluster_points, axis=0)
        all_centers.append(center)
        print(f"{cluster_name}: центр = {center}")

average_center = np.mean(all_centers, axis=0)
average_scaled = average_center * 1000
print(f"\nУсредненный центр * 1000 = {average_scaled}")
# Out:
# cluster_0: центральная точка = [0.04811155 8.05305091]
# cluster_0: центр = [0.08026234 7.85281407]
# cluster_1: центральная точка = [2.033901  5.2892959]
# cluster_1: центр = [2.10667952 5.29860857]
#
# Усредненный центр * 1000 = [1093.47092932 6575.71131612]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel("1.xls")

X = np.array(df['X'])
Y = np.array(df['Y'])

k_0 = 1
b_0 = -6.8

k_1 = -1.5
b_1 = 14

x_line_0 = [5, 11]
y_line_0 = [k_0 * 5 + b_0, k_0 * 11 + b_0]

x_line_1 = [8, 11]
y_line_1 = [k_1 * 8 + b_1, k_1 * 11 + b_1]


cluster_0_x = []
cluster_0_y = []

cluster_1_x = []
cluster_1_y = []

cluster_2_x = []
cluster_2_y = []


for i in range(len(X)):
    if Y[i] > k_0 * X[i] + b_0:
        cluster_0_x.append(X[i])
        cluster_0_y.append(Y[i])
    elif Y[i] > k_1 * X[i] + b_1:
        cluster_1_x.append(X[i])
        cluster_1_y.append(Y[i])
    else:
        cluster_2_x.append(X[i])
        cluster_2_y.append(Y[i])
# plt.plot(x_line_0, y_line_0, color="orange", label="line_0")
# plt.plot(x_line_1, y_line_1, color="red", label="line_1")

plt.scatter(cluster_0_x, cluster_0_y, color="blue", label="cluster_0")
plt.scatter(cluster_1_x, cluster_1_y, color="green", label="cluster_1")
plt.scatter(cluster_2_x, cluster_2_y, color="purple", label="cluster_2")

plt.grid(True)
plt.legend()
plt.show()

clusters = [
    (np.array([cluster_0_x, cluster_0_y]).T, "cluster_0"),
    (np.array([cluster_1_x, cluster_1_y]).T, "cluster_1"),
    (np.array([cluster_2_x, cluster_2_y]).T, "cluster_2")
]

all_centers = []
for cluster_points, cluster_name in clusters:
    if len(cluster_points) > 0:

        min_sum_dist = float('inf')
        central_point = None
        for i, point in enumerate(cluster_points):
            sum_dist = np.sum(np.sqrt(np.sum((cluster_points - point) ** 2, axis=1)))
            if sum_dist < min_sum_dist:
                min_sum_dist = sum_dist
                central_point = point
        print(f"{cluster_name}: центральная точка = {central_point}")
        
        center = np.mean(cluster_points, axis=0)
        all_centers.append(center)
        print(f"{cluster_name}: центр = {center}")

average_center = np.mean(all_centers, axis=0)
average_scaled = average_center * 1000
print(f"\nУсредненный центр * 1000 = {average_scaled}")
# Out:
# cluster_0: центральная точка = [6.46998257 2.169761  ]
# cluster_0: центр = [6.51286131 2.1723648 ]
# cluster_1: центральная точка = [10.02253531  1.1542006 ]
# cluster_1: центр = [10.01809877  1.1702465 ]
# cluster_2: центральная точка = [ 8.04007453 -1.10870557]
# cluster_2: центр = [ 8.03064864 -1.11215642]
#
# Усредненный центр * 1000 = [8187.20290544  743.48496005]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel("2.xlsx")

X = np.array(df.iloc[:, 0])
Y = np.array(df.iloc[:, 1])


k = 0
b = 0.5

x_line = [-0, 45]
y_line = [k * 0 + b, k * 45 + b]

cluster_0_x = []
cluster_0_y = []
cluster_1_x = []
cluster_1_y = []

for i in range(len(X)):
    if Y[i] > k * X[i] + b:
        cluster_0_x.append(X[i])
        cluster_0_y.append(Y[i])
    else:
        cluster_1_x.append(X[i])
        cluster_1_y.append(Y[i])
# plt.plot(x_line, y_line, color="red")
plt.scatter(cluster_0_x, cluster_0_y, color="blue", label="cluster_0")
plt.scatter(cluster_1_x, cluster_1_y, color="green", label="cluster_1")

plt.grid(True)
plt.legend()
plt.show()


clusters = [
    (np.array([cluster_0_x, cluster_0_y]).T, "cluster_0"),
    (np.array([cluster_1_x, cluster_1_y]).T, "cluster_1")
]

all_centers = []
for cluster_points, cluster_name in clusters:
    if len(cluster_points) > 0:
        min_sum_dist = float('inf')
        central_point = None
        for i, point in enumerate(cluster_points):
            sum_dist = np.sum(np.sqrt(np.sum((cluster_points - point) ** 2, axis=1)))
            if sum_dist < min_sum_dist:
                min_sum_dist = sum_dist
                central_point = point
        print(f"{cluster_name}: центральная точка = {central_point}")
        
        center = np.mean(cluster_points, axis=0)
        all_centers.append(center)
        print(f"{cluster_name}: центр = {center}")

average_center = np.mean(all_centers, axis=0)
average_scaled = average_center * 1000
print(f"\nУсредненный центр * 1000 = {average_scaled}")
# Out:
# cluster_0: центральная точка = [11.3340802   5.96596108]
# cluster_0: центр = [11.79914112  5.90797201]
# cluster_1: центральная точка = [34.92635132 -4.69527649]
# cluster_1: центр = [34.97637577 -4.61668646]
#
# Усредненный центр * 1000 = [23387.7584493    645.64277624]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel("3.xlsx")

X = np.array(df.iloc[:, 0])
Y = np.array(df.iloc[:, 1])

x_0 = -10
x_1 = 15

x_line_0 = [x_0, x_0]
y_line_0 = [-20, 10]


x_line_1 = [x_1, x_1]
y_line_1 = [-20, 10]


cluster_0_x = []
cluster_0_y = []
cluster_1_x = []
cluster_1_y = []
cluster_2_x = []
cluster_2_y = []

for i in range(len(X)):
    if X[i] < x_0:
        cluster_0_x.append(X[i])
        cluster_0_y.append(Y[i])
    elif X[i] < x_1:
        cluster_1_x.append(X[i])
        cluster_1_y.append(Y[i])
    else:
        cluster_2_x.append(X[i])
        cluster_2_y.append(Y[i])


# plt.plot(x_line_0, y_line_0, color="red")
# plt.plot(x_line_1, y_line_1, color="red")

plt.scatter(cluster_0_x, cluster_0_y, color="blue", label="cluster_0")
plt.scatter(cluster_1_x, cluster_1_y, color="green", label="cluster_1")
plt.scatter(cluster_2_x, cluster_2_y, color="purple", label="cluster_2")

plt.grid(True)
plt.legend()
plt.show()

clusters = [
    (np.array([cluster_0_x, cluster_0_y]).T, "cluster_0"),
    (np.array([cluster_1_x, cluster_1_y]).T, "cluster_1"),
    (np.array([cluster_2_x, cluster_2_y]).T, "cluster_2")
]

all_centers = []
for cluster_points, cluster_name in clusters:
    if len(cluster_points) > 0:

        min_sum_dist = float('inf')
        central_point = None

        for i, point in enumerate(cluster_points):
            sum_dist = np.sum(np.abs(cluster_points - point)) #манхетонское расстояние
            if sum_dist < min_sum_dist:
                min_sum_dist = sum_dist
                central_point = point
        print(f"{cluster_name}: центральная точка = {central_point}")
        
        center = np.mean(cluster_points, axis=0)
        all_centers.append(center)
        print(f"{cluster_name}: центр = {center}")

average_center = np.mean(all_centers, axis=0)
average_scaled = average_center * 1000
print(f"\nУсредненный центр * 1000 = {average_scaled}")
# Out:
# cluster_0: центральная точка = [-25.1307584  -14.41332836]
# cluster_0: центр = [-25.28939423 -14.41090076]
# cluster_1: центральная точка = [3.51791128 4.65369556]
# cluster_1: центр = [3.60554048 4.62156392]
# cluster_2: центральная точка = [30.84952916 -4.51720291]
# cluster_2: центр = [30.79669583 -4.60510133]
#
# Усредненный центр * 1000 = [ 3037.61402751 -4798.1460549 ]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_excel("4.xlsx")

X = np.array(df.iloc[:, 0])
Y = np.array(df.iloc[:, 1])

k = 1
b = 3

x_line = [-2, 6]
y_line = [k * -2 + b, k * 6 + b]

cluster_0_x = []
cluster_0_y = []
cluster_1_x = []
cluster_1_y = []

for i in range(len(X)):
    if Y[i] > k * X[i] + b:
        cluster_0_x.append(X[i])
        cluster_0_y.append(Y[i])
    else:
        cluster_1_x.append(X[i])
        cluster_1_y.append(Y[i])

# plt.plot(x_line, y_line, color="red")
plt.scatter(cluster_0_x, cluster_0_y, color="blue", label="cluster_0")
plt.scatter(cluster_1_x, cluster_1_y, color="green", label="cluster_1")

plt.grid(True)
plt.legend()
plt.show()

print("\n=== Анализ кластеров (манхетонское расстояние) ===")
clusters = [
    (np.array([cluster_0_x, cluster_0_y]).T, "cluster_0"),
    (np.array([cluster_1_x, cluster_1_y]).T, "cluster_1")
]

all_centers = []
for cluster_points, cluster_name in clusters:
    if len(cluster_points) > 0:
        min_sum_dist = float('inf')
        central_point = None
        for i, point in enumerate(cluster_points):
            sum_dist = np.sum(np.abs(cluster_points - point))  # Манхетонское расстояние
            if sum_dist < min_sum_dist:
                min_sum_dist = sum_dist
                central_point = point
        print(f"{cluster_name}: центральная точка = {central_point}")
        
        center = np.mean(cluster_points, axis=0)
        all_centers.append(center)
        print(f"{cluster_name}: центр = {center}")

average_center = np.mean(all_centers, axis=0)
average_scaled = average_center * 1000
print(f"\nУсредненный центр * 1000 = {average_scaled}")
# Out:
# === Анализ кластеров (манхетонское расстояние) ===
# cluster_0: центральная точка = [0.67779061 7.46832145]
# cluster_0: центр = [0.65307957 7.50416968]
# cluster_1: центральная точка = [4.49928923 2.52481355]
# cluster_1: центр = [4.60915771 2.59329389]
#
# Усредненный центр * 1000 = [2631.11864076 5048.73178565]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_excel("5.xlsx")

X = np.array(df.iloc[:, 0])
Y = np.array(df.iloc[:, 1])

k_0 = -1
b_0 = 2

x_line_0 = [-6, 6]
y_line_0 = [k_0 * -6 + b_0, k_0 * 6 + b_0]


k_1 = 1
b_1 = 4

x_line_1 = [0, 6]
y_line_1 = [k_1 * 0 + b_1, k_1 * 6 + b_1]


cluster_0_x = []
cluster_0_y = []

cluster_1_x = []
cluster_1_y = []

cluster_2_x = []
cluster_2_y = []


for i in range(len(X)):
    if Y[i] < k_0 * X[i] + b_0:
        cluster_0_x.append(X[i])
        cluster_0_y.append(Y[i])
    elif Y[i] > k_1 * X[i] + b_1:
        cluster_1_x.append(X[i])
        cluster_1_y.append(Y[i])
    else:
        cluster_2_x.append(X[i])
        cluster_2_y.append(Y[i])


# plt.plot(x_line_0, y_line_0, color="red")
# plt.plot(x_line_1, y_line_1, color="red")

plt.scatter(cluster_0_x, cluster_0_y, color="blue", label="cluster_0")
plt.scatter(cluster_1_x, cluster_1_y, color="green", label="cluster_1")
plt.scatter(cluster_2_x, cluster_2_y, color="purple", label="cluster_2")

plt.grid(True)
plt.legend()
plt.show()

clusters = [
    (np.array([cluster_0_x, cluster_0_y]).T, "cluster_0"),
    (np.array([cluster_1_x, cluster_1_y]).T, "cluster_1"),
    (np.array([cluster_2_x, cluster_2_y]).T, "cluster_2")
]

all_centers = []
for cluster_points, cluster_name in clusters:
    if len(cluster_points) > 0:
        min_sum_dist = float('inf')
        central_point = None
        for i, point in enumerate(cluster_points):
            sum_dist = np.sum(np.sqrt(np.sum((cluster_points - point) ** 2, axis=1)))
            if sum_dist < min_sum_dist:
                min_sum_dist = sum_dist
                central_point = point
        print(f"{cluster_name}: центральная точка = {central_point}")
        
        center = np.mean(cluster_points, axis=0)
        all_centers.append(center)
        print(f"{cluster_name}: центр = {center}")

average_center = np.mean(all_centers, axis=0)
average_scaled = average_center * 1000
print(f"\nУсредненный центр * 1000 = {average_scaled}")
# Out:
# cluster_0: центральная точка = [-2.74967383  1.14305932]
# cluster_0: центр = [-2.78699258  1.13266604]
# cluster_1: центральная точка = [-0.92395442  7.11986015]
# cluster_1: центр = [-0.90264658  7.13762322]
# cluster_2: центральная точка = [3.85858481 2.90716697]
# cluster_2: центр = [3.87584162 2.95278937]
#
# Усредненный центр * 1000 = [  62.06748517 3741.02621158]

# %% [markdown]
# # Кластеризация (0.75 за каждый алгоритм на всех данных)

# %% [markdown]
# На предложенных распределениях данных проверьте предложенные алгоритмы. Постройте графики кластеризации для каждой пары алгоритм-данные, разные кластеры покрасьте разным цветом. Воспользуйтесь sklearn реализациями. Параметры кластеризации для разных алгоритмов подберите такие, чтобы алгоритмы можно было сравнивать (по возможности одинаковое количество кластеров и т.д.)

# %%
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

# %%
two_means = cluster.MiniBatchKMeans(init="k-means++", n_clusters=3, n_init=5, random_state=0)
dbscan = cluster.DBSCAN(eps=0.3)

clustering_algorithms = (
        ("MiniBatch\nKMeans", two_means),
        ("DBSCAN", dbscan),
    )

# %%
np.random.seed(0)
# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# ============
# Set up cluster parameters
# ============
plt.figure(figsize=(9 * 2 + 3, 13))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.2, hspace=0.3
)

plot_num = 1

default_base = {
    "quantile": 0.3,
    "eps": 0.3,
    "damping": 0.9,
    "preference": -200,
    "n_neighbors": 10,
    "n_clusters": 3,
    "min_samples": 20,
    "xi": 0.05,
    "min_cluster_size": 0.1,
}

datasets_list = [
    (
        noisy_circles,
        {
            "damping": 0.77,
            "preference": -240,
            "quantile": 0.2,
            "n_clusters": 2,
            "min_samples": 20,
            "xi": 0.25,
        },
    ),
    (noisy_moons, {"damping": 0.75, "preference": -220, "n_clusters": 2}),
    (
        varied,
        {
            "eps": 0.18,
            "n_neighbors": 2,
            "min_samples": 5,
            "xi": 0.035,
            "min_cluster_size": 0.2,
        },
    ),
    (
        aniso,
        {
            "eps": 0.15,
            "n_neighbors": 2,
            "min_samples": 20,
            "xi": 0.1,
            "min_cluster_size": 0.2,
        },
    ),
    (blobs, {}),
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets_list):
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    X = StandardScaler().fit_transform(X)

    bandwidth = cluster.estimate_bandwidth(X, quantile=params["quantile"])

    connectivity = kneighbors_graph(
        X, n_neighbors=params["n_neighbors"], include_self=False
    )
    connectivity = 0.5 * (connectivity + connectivity.T)

    for name, algorithm in clustering_algorithms:
        t0 = time.time()
        
        algorithm.fit(X)
        t1 = time.time()
        if hasattr(algorithm, "labels_"):
            y_pred = algorithm.labels_.astype(np.int64)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets_list), len(clustering_algorithms), plot_num)
        
        unique_labels = np.unique(y_pred)
        custom_colors = ['#2ecc71', '#3498db', '#9b59b6']  # green, blue, purple
        colors = [custom_colors[i % len(custom_colors)] for i in range(len(unique_labels))]
        
        for k, col in zip(unique_labels, colors):
            if k == -1:
                col = [0, 0, 0, 1]

            class_member_mask = y_pred == k
            xy = X[class_member_mask]
            plt.scatter(xy[:, 0], xy[:, 1], c=[col], s=10)

        plt.title(name, size=18)
        plt.xticks(())
        plt.yticks(())
        plt.text(0.99, 0.01, ("%.2fs" % (t1 - t0)).lstrip("0"), transform=plt.gca().transAxes, size=15, horizontalalignment="right")
        plot_num += 1

plt.show()
